# %% [markdown]
# # WWE WRESTLERS🤼‍♂️💥

# %% [markdown]
# * Libraries💻

# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# * Importing the .csv file✅

# %%
wrestlers = pd.read_csv("/Users/lauurasarabia/Ironhack/projects/Project-2/data/data.csv")
wrestlers
# Out:
#                  name  reign  days       date              event  \
# 0        Buddy Rogers      1    36  11-Apr-63         House show
# 1    Bruno Sammartino      1  2803  17-May-63         House show
# 2         Ivan Koloff      1    21  18-Jan-71         House show
# 3       Pedro Morales      1  1027   8-Feb-71         House show
# 4        Stan Stasiak      1     9   1-Dec-73         House show
# ..                ...    ...   ...        ...                ...
# 407       Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408   Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409            Bayley      1   140  19-May-19  Money in the Bank
# 410   Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411            Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                           link  \
# 0       Washington, D.C.  /wiki/Buddy_Rogers_(wrestler)
# 1           New York, NY         /wiki/Bruno_Sammartino
# 2           New York, NY              /wiki/Ivan_Koloff
# 3           New York, NY            /wiki/Pedro_Morales
# 4       Philadelphia, PA             /wiki/Stan_Stasiak
# ..                   ...                            ...
# 407  East Rutherford, NJ              /wiki/Becky_Lynch
# 408         Hartford, CT          /wiki/Charlotte_Flair
# 409         Hartford, CT        /wiki/Bayley_(wrestler)
# 410       Sacramento, CA          /wiki/Charlotte_Flair
# 411         Paradise, NV        /wiki/Bayley_(wrestler)
#
#                                    belt date_of_birth date_of_death  \
# 0                      WWE Championship     2/20/1921     6/26/1992
# 1                      WWE Championship     10/6/1935     4/18/2018
# 2                      WWE Championship     8/25/1942     2/18/2017
# 3                      WWE Championship    10/22/1942     2/12/2019
# 4                      WWE Championship     4/13/1937     6/19/1997
# ..                                  ...           ...           ...
# 407  WWE SmackDown Women's Championship     1/30/1987           NaN
# 408  WWE SmackDown Women's Championship      4/5/1986           NaN
# 409  WWE SmackDown Women's Championship     6/15/1989           NaN
# 410  WWE SmackDown Women's Championship      4/5/1986           NaN
# 411  WWE SmackDown Women's Championship     6/15/1989           NaN
#
#                                       cause_of_death
# 0                                                NaN
# 1    Multiple organ failure due to heart problems[2]
# 2                                       Liver cancer
# 3                                                NaN
# 4                                      Heart failure
# ..                                               ...
# 407                                              NaN
# 408                                              NaN
# 409                                              NaN
# 410                                              NaN
# 411                                              NaN
#
# [412 rows x 11 columns]

# %% [markdown]
# * Dropping the columns which will not be used for the analysis🧨

# %%
wrestlers.drop(["link", "date_of_death", "cause_of_death"], axis=1, inplace=True)

# %% [markdown]
# * Changing date format in "date_of_birth" column in order to be able to filter by date📆

# %%
#Change date format from "mm/dd/YYYY" to "dd/mm/YYYY" and remove the "YYYY" as we won't use it
wrestlers['date_of_birth'] = pd.to_datetime(wrestlers['date_of_birth'], format="%m/%d/%Y")
wrestlers['DOB'] = wrestlers['date_of_birth'].dt.strftime("%d/%m")

#Add same year for all dates in order to be able to compare them
wrestlers['DOB'] = wrestlers['DOB'] + "/2023"

wrestlers['DOB'] = pd.to_datetime(wrestlers['DOB'], format="%d/%m/%Y")

# %% [markdown]
# * Let's find out which horoscope are they🧐

# %%
# Pass the conditions for each horoscope
conditions = [
    (wrestlers['DOB'] >= "2023-12-22") & (wrestlers['DOB'] <= "2023-01-19"),
    (wrestlers['DOB'] >= "2023-01-20") & (wrestlers['DOB'] <= "2023-02-18"),
    (wrestlers['DOB'] >= "2023-02-19") & (wrestlers['DOB'] <= "2023-03-20"),
    (wrestlers['DOB'] >= "2023-03-21") & (wrestlers['DOB'] <= "2023-04-19"),
    (wrestlers['DOB'] >= "2023-04-20") & (wrestlers['DOB'] <= "2023-05-20"),
    (wrestlers['DOB'] >= "2023-05-21") & (wrestlers['DOB'] <= "2023-06-20"),
    (wrestlers['DOB'] >= "2023-06-21") & (wrestlers['DOB'] <= "2023-07-22"),
    (wrestlers['DOB'] >= "2023-07-23") & (wrestlers['DOB'] <= "2023-08-23"),
    (wrestlers['DOB'] >= "2023-08-23") & (wrestlers['DOB'] <= "2023-09-22"),
    (wrestlers['DOB'] >= "2023-08-23") & (wrestlers['DOB'] <= "2023-10-22"),
    (wrestlers['DOB'] >= "2023-10-23") & (wrestlers['DOB'] <= "2023-11-21"),
    (wrestlers['DOB'] >= "2023-11-22") & (wrestlers['DOB'] <= "2023-12-21"),
    ]

values = [
    "Capricorn", "Aquarius", "Pisces", "Aries", "Taurus", "Gemini", 
    "Cancer", "Leo", "Virgo", "Libra", "Scorpio","Sagittarius",
    ]

wrestlers["Horoscope"] = np.select(conditions, values)
wrestlers
# Out:
#                  name  reign  days       date              event  \
# 0        Buddy Rogers      1    36  11-Apr-63         House show
# 1    Bruno Sammartino      1  2803  17-May-63         House show
# 2         Ivan Koloff      1    21  18-Jan-71         House show
# 3       Pedro Morales      1  1027   8-Feb-71         House show
# 4        Stan Stasiak      1     9   1-Dec-73         House show
# ..                ...    ...   ...        ...                ...
# 407       Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408   Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409            Bayley      1   140  19-May-19  Money in the Bank
# 410   Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411            Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                                belt date_of_birth  \
# 0       Washington, D.C.                    WWE Championship    1921-02-20
# 1           New York, NY                    WWE Championship    1935-10-06
# 2           New York, NY                    WWE Championship    1942-08-25
# 3           New York, NY                    WWE Championship    1942-10-22
# 4       Philadelphia, PA                    WWE Championship    1937-04-13
# ..                   ...                                 ...           ...
# 407  East Rutherford, NJ  WWE SmackDown Women's Championship    1987-01-30
# 408         Hartford, CT  WWE SmackDown Women's Championship    1986-04-05
# 409         Hartford, CT  WWE SmackDown Women's Championship    1989-06-15
# 410       Sacramento, CA  WWE SmackDown Women's Championship    1986-04-05
# 411         Paradise, NV  WWE SmackDown Women's Championship    1989-06-15
#
#            DOB Horoscope
# 0   2023-02-20    Pisces
# 1   2023-10-06     Libra
# 2   2023-08-25     Virgo
# 3   2023-10-22     Libra
# 4   2023-04-13     Aries
# ..         ...       ...
# 407 2023-01-30  Aquarius
# 408 2023-04-05     Aries
# 409 2023-06-15    Gemini
# 410 2023-04-05     Aries
# 411 2023-06-15    Gemini
#
# [412 rows x 10 columns]

# %% [markdown]
# * Giving final touches to columns🪄

# %%
wrestlers = wrestlers.rename(columns={"name":"Name",
                                      "date": "Date",
                                      "reign":"Reign",
                                      "days":"Days",
                                      "event":"Event",
                                      "location":"Location",
                                      "belt":"Belt",
                                     })

# %%
wrestlers.head(10)
# Out:
#                      Name  Reign  Days       Date               Event  \
# 0            Buddy Rogers      1    36  11-Apr-63          House show
# 1        Bruno Sammartino      1  2803  17-May-63          House show
# 2             Ivan Koloff      1    21  18-Jan-71          House show
# 3           Pedro Morales      1  1027   8-Feb-71          House show
# 4            Stan Stasiak      1     9   1-Dec-73          House show
# 5        Bruno Sammartino      2  1237  10-Dec-73          House show
# 6  Superstar Billy Graham      1   296  30-Apr-77          House show
# 7            Bob Backlund      1   648  20-Feb-78  WWF on MSG Network
# 8           Antonio Inoki      1     6  30-Nov-79          House show
# 9            Bob Backlund      2  1470  17-Dec-79  WWF on MSG Network
#
#            Location              Belt date_of_birth        DOB Horoscope
# 0  Washington, D.C.  WWE Championship    1921-02-20 2023-02-20    Pisces
# 1      New York, NY  WWE Championship    1935-10-06 2023-10-06     Libra
# 2      New York, NY  WWE Championship    1942-08-25 2023-08-25     Virgo
# 3      New York, NY  WWE Championship    1942-10-22 2023-10-22     Libra
# 4  Philadelphia, PA  WWE Championship    1937-04-13 2023-04-13     Aries
# 5      New York, NY  WWE Championship    1935-10-06 2023-10-06     Libra
# 6     Baltimore, MD  WWE Championship    1943-06-07 2023-06-07    Gemini
# 7      New York, NY  WWE Championship    1949-08-14 2023-08-14       Leo
# 8  Tokushima, Japan  WWE Championship    1943-02-20 2023-02-20    Pisces
# 9      New York, NY  WWE Championship    1949-08-14 2023-08-14       Leo

# %%
wrestlers['DOB'] = wrestlers['date_of_birth'].dt.strftime("%d/%m")

# %%
wrestlers.drop(columns='date_of_birth', inplace=True)

# %%
wrestlers.head(10)
# Out:
#                      Name  Reign  Days       Date               Event  \
# 0            Buddy Rogers      1    36  11-Apr-63          House show
# 1        Bruno Sammartino      1  2803  17-May-63          House show
# 2             Ivan Koloff      1    21  18-Jan-71          House show
# 3           Pedro Morales      1  1027   8-Feb-71          House show
# 4            Stan Stasiak      1     9   1-Dec-73          House show
# 5        Bruno Sammartino      2  1237  10-Dec-73          House show
# 6  Superstar Billy Graham      1   296  30-Apr-77          House show
# 7            Bob Backlund      1   648  20-Feb-78  WWF on MSG Network
# 8           Antonio Inoki      1     6  30-Nov-79          House show
# 9            Bob Backlund      2  1470  17-Dec-79  WWF on MSG Network
#
#            Location              Belt    DOB Horoscope
# 0  Washington, D.C.  WWE Championship  20/02    Pisces
# 1      New York, NY  WWE Championship  06/10     Libra
# 2      New York, NY  WWE Championship  25/08     Virgo
# 3      New York, NY  WWE Championship  22/10     Libra
# 4  Philadelphia, PA  WWE Championship  13/04     Aries
# 5      New York, NY  WWE Championship  06/10     Libra
# 6     Baltimore, MD  WWE Championship  07/06    Gemini
# 7      New York, NY  WWE Championship  14/08       Leo
# 8  Tokushima, Japan  WWE Championship  20/02    Pisces
# 9      New York, NY  WWE Championship  14/08       Leo

# %%
wrestlers.to_csv('/Users/lauurasarabia/Ironhack/projects/Project-2/data/WWE_Wrestlers.csv')
